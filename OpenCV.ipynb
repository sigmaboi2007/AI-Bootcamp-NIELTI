# %%
import cv2
from google.colab.patches import cv2_imshow

image_path = '/content/yeah.jpg'

image = cv2.imread(image_path)

if image is None:
  print(f"image not found at {image_path} damn!")
else:
  cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=320x237>
